# %%
# %pylab inline
# %config InlineBackend.figure_format = 'svg'
from __future__ import division
import seaborn as sns
import sklearn as sk
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from nltk.stem.snowball import SnowballStemmer
import pandas as pd
import sys
from IPython.core.display import display, HTML
sns.set_context({'figure.figsize': [12, 7]})
sns.set_context(rc={'lines.markeredgewidth': 0.1})
sns.set_style('white')
sns.set_color_codes()
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.preprocessing import normalize
from sklearn.manifold import TSNE
from sklearn.utils import resample
from sklearn import metrics
from sklearn.metrics import pairwise_distances
import glob
import os
print 'startup script successful'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# startup script successful

# %%
crunch_data=pd.read_csv('overall_company_list.csv', index_col=0)
kickstart_data=pd.read_csv('proj_list_tech_top200pages_full.csv')
angellist_data=pd.read_csv('results_so_far_2016101710pm.csv', index_col=0)

# %%
acq_file_list = glob.glob('cb_acquisitions/*csv')
dfs = []
for f in acq_file_list:
    dfs.append(pd.read_csv(f))
acq_df = pd.concat(dfs, ignore_index=True)
#print acq_df['Acquired Company Name']

# %%
cb_cname = crunch_data['Company Name']
acq_cname = acq_df['Acquired Company Name']
print len(set(acq_cname))
print len(set(cb_cname.values) & set(acq_cname.values))
# Out:
# 3729
# 389

# %%
# print crunch_data.shape
# print crunch_data.columns
# print acq_df.columns
crunch_data_merged = crunch_data.merge(acq_df, how='left', left_on='Company Name', right_on='Acquired Company Name')
# print crunch_data_merged.shape
# print crunch_data_merged.columns
#crunch_data_merged[crunch_data_merged['Acquired Company Name'].notnull()]

# %%
df_dict = dict()
df_dict['cb'] = crunch_data_merged
# df_dict['cb_acq'] = acq_df
df_dict['ks'] = kickstart_data
df_dict['al'] = angellist_data

# %%
for key, item in df_dict.iteritems():
    print key, item.shape
    print item.columns
# Out:
# ks (3988, 12)
# Index([u'active', u'byline', u'city', u'currency', u'description', u'end_date',
#        u'funded_amt', u'funded_pct', u'headline', u'state', u'title', u'url'],
#       dtype='object')
# cb (11931, 33)
# Index([u'Company Name', u'Category Groups', u'Headquarters Location',
#        u'Description', u'Crunchbase Rank', u'Founded Date',
#        u'Number of Articles', u'Total Equity Funding Amount',
#        u'Total Funding Amount', u'Closed Date', u'Categories', u'Status',
#        u'Number of Founders', u'Number of Employees', u'Last Funding Date',
#        u'Last Funding Amount', u'Last Equity Funding Amount',
#        u'Number of Investors', u'IPO Date', u'Money Raised at IPO',
#        u'Valuation at IPO', u'Stock Symbol', u'Stock Exchange',
#        u'Trend Score (7 Days)', u'Trend Score (30 Days)',
#        u'Trend Score (90 Days)', u'Website', u'year', u'Transaction Name',
#        u'Acquired Company Name', u'Acquiring Company Name',
#        u'Announced On Date', u'Price'],
#       dtype='object')
# al (6194, 13)
# Index([u'al_link', u'featured', u'joined_date', u'location', u'market',
#        u'product_desc', u'raised', u'signal', u'size', u'stage', u'title',
#        u'website', u'score'],
#       dtype='object')

# %%
df_dict['ks']['data_source'] = 'kickstarter'
df_dict['ks'].rename(columns={'description':'description', 'title': 'company_name'},inplace=True)

df_dict['cb']['data_source'] = 'crunchbase'
df_dict['cb'].rename(columns={'Description':'description', 'Company Name': 'company_name'},inplace=True)
df_dict['cb']['acquired'] = df_dict['cb']['Acquired Company Name'].notnull().astype(int)

df_dict['al']['data_source'] = 'angellist'
df_dict['al'].rename(columns={'product_desc':'description', 'title': 'company_name'},inplace=True)
df_dict['al']['acquired'] = (df_dict['al']['stage']=='Acquired').astype(int)

# %%
for key, item in df_dict.iteritems():
    print key, item.shape
    print item.columns
# Out:
# ks (3988, 13)
# Index([u'active', u'byline', u'city', u'currency', u'description', u'end_date',
#        u'funded_amt', u'funded_pct', u'headline', u'state', u'company_name',
#        u'url', u'data_source'],
#       dtype='object')
# cb (11931, 35)
# Index([u'company_name', u'Category Groups', u'Headquarters Location',
#        u'description', u'Crunchbase Rank', u'Founded Date',
#        u'Number of Articles', u'Total Equity Funding Amount',
#        u'Total Funding Amount', u'Closed Date', u'Categories', u'Status',
#        u'Number of Founders', u'Number of Employees', u'Last Funding Date',
#        u'Last Funding Amount', u'Last Equity Funding Amount',
#        u'Number of Investors', u'IPO Date', u'Money Raised at IPO',
#        u'Valuation at IPO', u'Stock Symbol', u'Stock Exchange',
#        u'Trend Score (7 Days)', u'Trend Score (30 Days)',
#        u'Trend Score (90 Days)', u'Website', u'year', u'Transaction Name',
#        u'Acquired Company Name', u'Acquiring Company Name',
#        u'Announced On Date', u'Price', u'data_source', u'acquired'],
#       dtype='object')
# al (6194, 15)
# Index([u'al_link', u'featured', u'joined_date', u'location', u'market',
#        u'description', u'raised', u'signal', u'size', u'stage',
#        u'company_name', u'website', u'score', u'data_source', u'acquired'],
#       dtype='object')

# %%
merge_data=pd.concat([x for _, x in df_dict.iteritems()], ignore_index=True)
print merge_data.shape
merge_data.drop_duplicates(inplace=True)
print merge_data.shape
# Out:
# (22113, 56)
# (18599, 56)

# %%
merge_data.data_source.value_counts()
# Out:
# crunchbase     8417
# angellist      6194
# kickstarter    3988
# Name: data_source, dtype: int64

# %%
print merge_data.columns
# Out:
# Index([u'Acquired Company Name', u'Acquiring Company Name',
#        u'Announced On Date', u'Categories', u'Category Groups', u'Closed Date',
#        u'Crunchbase Rank', u'Founded Date', u'Headquarters Location',
#        u'IPO Date', u'Last Equity Funding Amount', u'Last Funding Amount',
#        u'Last Funding Date', u'Money Raised at IPO', u'Number of Articles',
#        u'Number of Employees', u'Number of Founders', u'Number of Investors',
#        u'Price', u'Status', u'Stock Exchange', u'Stock Symbol',
#        u'Total Equity Funding Amount', u'Total Funding Amount',
#        u'Transaction Name', u'Trend Score (30 Days)', u'Trend Score (7 Days)',
#        u'Trend Score (90 Days)', u'Valuation at IPO', u'Website', u'acquired',
#        u'active', u'al_link', u'byline', u'city', u'company_name', u'currency',
#        u'data_source', u'description', u'end_date', u'featured', u'funded_amt',
#        u'funded_pct', u'headline', u'joined_date', u'location', u'market',
#        u'raised', u'score', u'signal', u'size', u'stage', u'state', u'url',
#        u'website', u'year'],
#       dtype='object')

# %%
merge_data_select = merge_data[['company_name', 'description', 'data_source', 'acquired']]

# %%
#merge_data_select[merge_data_select['company_name']=='The']
merge_data_select = merge_data_select[(merge_data_select.data_source=='crunchbase') | (merge_data_select.data_source=='angellist')]

# %%
#merge_data_select.company_name.value_counts()
merge_data_select = merge_data_select.drop_duplicates()
merge_data_select['description']=merge_data_select['description'].str.replace('\n',' ')
# merge_data['Description']=merge_data['Description'].str.replace('\\',' ')

merge_data_select=merge_data_select.dropna(subset=['description'])

# %%
import seaborn as sns
import sklearn as sk
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from nltk.stem.snowball import SnowballStemmer
import pandas as pd
import sys
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.preprocessing import normalize
from sklearn.manifold import TSNE
from sklearn.utils import resample
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.cluster import AgglomerativeClustering
from nltk.stem import WordNetLemmatizer
import re
from nltk.corpus import stopwords


token_pattern = re.compile(r"(?u)\b\w\w+\b")
stop_list=stopwords.words('english')+['help','new', 'way', 'world', 'make', 'people']

import itertools
palette = itertools.cycle(sns.hls_palette(15))
markers= itertools.cycle(['x','o','v','^','<','s'])


def print_top_words(model, feature_names, n_top_words=20):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()


class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in token_pattern.findall(doc)]
    
def plot_top_words(model, feature_names, topic_idx, n_top_words=10):
#     for topic_idx, topic in enumerate(model.components_):
    topic=normalize(model.components_[topic_idx].reshape(1,-1))[0]
    sorted_idx=topic.argsort()[:-n_top_words - 1:-1]
    print("Topic #%d:" % topic_idx)
    features=[feature_names[i] for i in sorted_idx]
    print(" ".join(features))
    ax = sns.barplot(x=range(10),y=topic[sorted_idx])
    feature_id=0
    height= max(topic[sorted_idx])*0.6

    for p in ax.patches:
        ax.text(p.get_x()+0.15, height-0.1, '{}'.format(features[feature_id]))
        feature_id+=1

def plot_cluster(model, features, tsne_features, feature_names, nmf_model):
    """
    model: the clustering model. model.labels_ should contain the clusting label
    features: feature vectors used to compute the clustering centroid
    tsne_features: feature vectors for plot with tsne
    """
    cluster_labels=model.labels_
    n_top_words=10
    num_clusters=max(cluster_labels)+1
    cluster_name=[]
    # plotting
    # sample 2000 data points for scattering plot
    sample_for_plt, label_for_plt=resample(tsne_features,cluster_labels,n_samples=2000,random_state=0)
    mapping = TSNE(n_components=2,init='random', random_state=0, n_iter=2000, verbose=0, learning_rate=100, perplexity=20)
    embed=mapping.fit_transform(sample_for_plt)
    fig=figure(figsize=(15,7))
    # plot the clusters
    subplot(1,2,1)
    for i in range(num_clusters):
        subgroup=embed[label_for_plt==i,:]
        scatter(subgroup[:,0],subgroup[:,1],s=15, color=next(palette), marker=next(markers), label='{}'.format(i))
    legend()
    # plot the histgram of the clusters 
    subplot(1,2,2)
    hist(cluster_labels)
    # print out the cluster centers
    fig=figure(figsize=(15,10))
    for i in range(max(cluster_labels)+1):
        cluster=features[cluster_labels==i,:]
        centroid=np.mean(cluster,axis=0)
        centroid_feature=centroid.dot(nmf_model.components_)
        sorted_idx=centroid_feature.argsort()[:-n_top_words - 1:-1]
        c_name=' '.join([feature_names[j] for j in sorted_idx[:3]])
        cluster_name.append(c_name)
        subplot(num_clusters,1,i+1)
        ax = sns.barplot(x=range(10),y=centroid_feature[sorted_idx])
        top_words=[feature_names[j] for j in sorted_idx]
        word_id=0
        height= max(centroid_feature[sorted_idx])*0.6
        for p in ax.patches:
            ax.text(p.get_x()+0.15, height, '{}'.format(top_words[word_id]))
            word_id+=1
    return cluster_name

def print_cluster_member(model, cluster_id, data, num_samples=10):
    cluster_member=data.iloc[model.labels_==cluster_id]
    print 'number of companies in this class:', len(cluster_member)
    for m in cluster_member.head(num_samples).iterrows():
        print 'company ID:', m[0]
        print m[1]['Description']

def cluster_companies(df_data, description_column_name, num_clusters):
    """
    df_data: company dataframe
    description_column_name: column name of the dataframe corresponding to company description
    num_clusters: number of clusters 
    """
    tfidf_vectorizer = TfidfVectorizer(max_df=0.9, min_df=2,
                                       max_features=3000,
                                       tokenizer=LemmaTokenizer(),
                                       stop_words=stop_list)
    tfidf = tfidf_vectorizer.fit_transform(df_data[description_column_name])
    nmf = NMF(n_components=15, random_state=1, 
              alpha=.1, l1_ratio=.2, max_iter=5000).fit(tfidf)
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    topic_feature=nmf.transform(tfidf)
    topic_feature_norm=normalize(topic_feature)
    agg= AgglomerativeClustering(n_clusters=num_clusters, linkage='ward')
    agg.fit(topic_feature_norm)
    df_data['cluster_id']=agg.labels_
    cluster_name= plot_cluster(agg, topic_feature, topic_feature_norm, tfidf_feature_names, nmf)
    df_data['cluster_name']= df_data['cluster_id'].apply(lambda x: cluster_name[x])

# %%
cluster_companies(df_data=merge_data_select, description_column_name='description', num_clusters=10)

# %%
merge_data_select.columns
# Out:
# Index([u'company_name', u'description', u'data_source', u'acquired',
#        u'cluster_id', u'cluster_name'],
#       dtype='object')

# %%
merge_data_select
# Out:
#                            company_name  \
# 3988                               Krux
# 3989                            Datadog
# 3990                         Sumo Logic
# 3991                               Quid
# 3992                          Vicarious
# 3993                      Alteryx, Inc.
# 3994                            PlaceIQ
# 3995                              Qubit
# 3996                   Euclid Analytics
# 3997                              Infer
# 3998                           Nanigans
# 3999                           True Fit
# 4000                  Narrative Science
# 4001                        Flyby Media
# 4002                          OpenHouse
# 4003                            Bidgely
# 4004                            Diffbot
# 4005                    Simply Measured
# 4006                           GridGain
# 4007                Sidecar Interactive
# 4008                 Comprehend Systems
# 4009                             AiCure
# 4010                            MyLikes
# 4011                        Influenster
# 4012         PlaySight Interactive Ltd.
# 4013                          Neogrowth
# 4014             Trax Image Recognition
# 4015                 FirstFuel Software
# 4016                 Slice Technologies
# 4017                        SimpleReach
# ...                                 ...
# 22057                           TeamDom
# 22058                          Learndot
# 22059                             Lennd
# 22061                     Toshl Finance
# 22075                     Orchestra One
# 22076                             Aidin
# 22078                            iodine
# 22079                    Visible Health
# 22082                      Current Labs
# 22083   Internet of Things by Flight.vc
# 22085                           Toymail
# 22086                            Kelvin
# 22087                            Moxxly
# 22088                           Arryved
# 22090      Stealth Consumer IoT Company
# 22091                             HIPOM
# 22092                              Kuna
# 22093                             Nebia
# 22094                           MoBagel
# 22095                             Shape
# 22096  iWABOO. You Make it. We sell it.
# 22097                        ProFounder
# 22098                               ?dn
# 22099                            Xberts
# 22101                            Dextro
# 22102                          Forkable
# 22103                             Mavin
# 22104                Standard Analytics
# 22108                         Echo Labs
# 22111                         CrowdCall
#
#                                              description data_source  \
# 3988   Krux helps marketers, publishers and agencies ...  crunchbase
# 3989   Datadog is the essential monitoring service fo...  crunchbase
# 3990   Sumo Logic, a log management and analytics ser...  crunchbase
# 3991   Quid powers human intuition with machine intel...  crunchbase
# 3992   Vicarious develops Recursive Cortical Network™...  crunchbase
# 3993   Alteryx is the leader in self-service data ana...  crunchbase
# 3994   PlaceIQ provides location intelligence service...  crunchbase
# 3995   Qubit gives marketers the tools to understand ...  crunchbase
# 3996   Euclid Analytics is the world leader in locati...  crunchbase
# 3997   Infer provides a predictive SaaS platform that...  crunchbase
# 3998   Nanigans advertising automation software power...  crunchbase
# 3999           Footwear and apparel’s discovery platform  crunchbase
# 4000   Narrative Science is the leader in Advanced Na...  crunchbase
# 4001   Flyby Media develops next-generation consumer ...  crunchbase
# 4002   OpenHouse is a better way to find your dream h...  crunchbase
# 4003   Bidgely is a disruptive technology company dev...  crunchbase
# 4004   Diffbot is an AI startup that provides knowled...  crunchbase
# 4005   Simply Measured provides social media analytic...  crunchbase
# 4006   Leading Innovator in open source and commercia...  crunchbase
# 4007   Sidecar is machine learning technology that le...  crunchbase
# 4008   Comprehend is a technology company with a new ...  crunchbase
# 4009   Advanced medication adherence solutions powere...  crunchbase
# 4010   MyLikes is the World's Largest Social Website ...  crunchbase
# 4011   A product discovery and reviews platform that ...  crunchbase
# 4012   PlaySight is connecting the next generation of...  crunchbase
# 4013   NeoGrowth Credit Pvt Ltd is a non-deposit taki...  crunchbase
# 4014   The consumer goods industry’s leading real-tim...  crunchbase
# 4015   FirstFuel provides an analytics based customer...  crunchbase
# 4016     Slice Technologies is online shopping, smarter.  crunchbase
# 4017   SimpleReach is the standard in content measure...  crunchbase
# ...                                                  ...         ...
# 22057  TeamDom is a modern­day media conglomerate foc...   angellist
# 22058  This year, 8 billion USD will be spent on inte...   angellist
# 22059  Lennd is a operating system for the event prod...   angellist
# 22061  Making finance fun through innovative UI and a...   angellist
# 22075  Orchestra One is a healthcare marketplace and ...   angellist
# 22076  Aidin is a web application used by hospitals t...   angellist
# 22078  Iodine is a new kind of healthcare company on ...   angellist
# 22079  Visible Health is empowering physicians and ot...   angellist
# 22082  Aquatic ecosystems, from the beautiful aquariu...   angellist
# 22083  The IOT syndicate will be investing in hardwar...   angellist
# 22085  Ninety-Five percent of kids under 10 do not ha...   angellist
# 22086  Kelvin uses machine learning to power predicti...   angellist
# 22087  Moxxly is a female-founded, venture-backed sta...   angellist
# 22088  Arryved and Venyu work together to enhance the...   angellist
# 22090  Funded connected device company creating a new...   angellist
# 22091  HIPOM Inc. has developed an innovative and def...   angellist
# 22092  Every other home security solution on the mark...   angellist
# 22093  Our showerhead design and proprietary technolo...   angellist
# 22094  MoBagel is an advanced device management and p...   angellist
# 22095  ShapeScale is a weight scale that digitizes yo...   angellist
# 22096  iWABOO (500Startup B#15) is the first online B...   angellist
# 22097  ProFounder does two things: a YPO-like collect...   angellist
# 22098  ēdn is a Techstars company who introduced the ...   angellist
# 22099  Xberts is a cross-border hardware marketplace ...   angellist
# 22101  Dextro makes video searchable, curatable, and ...   angellist
# 22102  Forkable is using machine learning to conquer ...   angellist
# 22103  Mavin provides mobile internet strategic leade...   angellist
# 22104      Organizing the world's scientific information   angellist
# 22108  Echo Labs provides health care payers with rea...   angellist
# 22111  CrowdCall™ is disrupting the multi-billion dol...   angellist
#
#        acquired  cluster_id                      cluster_name
# 3988        1.0           0         social platform marketing
# 3989        0.0           9                service cloud data
# 3990        0.0           1  business intelligence artificial
# 3991        0.0           1  business intelligence artificial
# 3992        0.0           4             customer product user
# 3993        0.0           9                service cloud data
# 3994        0.0           1  business intelligence artificial
# 3995        0.0           5                    real time data
# 3996        0.0           6         analytics data predictive
# 3997        0.0           1  business intelligence artificial
# 3998        0.0           0         social platform marketing
# 3999        0.0           0         social platform marketing
# 4000        0.0           8                 data big platform
# 4001        1.0           0         social platform marketing
# 4002        0.0           4             customer product user
# 4003        0.0           3        software solution provides
# 4004        0.0           9                service cloud data
# 4005        0.0           0         social platform marketing
# 4006        0.0           8                 data big platform
# 4007        0.0           0         social platform marketing
# 4008        0.0           3        software solution provides
# 4009        0.0           1  business intelligence artificial
# 4010        0.0           0         social platform marketing
# 4011        0.0           0         social platform marketing
# 4012        0.0           6         analytics data predictive
# 4013        0.0           1  business intelligence artificial
# 4014        0.0           5                    real time data
# 4015        0.0           1  business intelligence artificial
# 4016        1.0           7       company technology research
# 4017        0.0           4             customer product user
# ...         ...         ...                               ...
# 22057       0.0           1  business intelligence artificial
# 22058       0.0           4             customer product user
# 22059       0.0           0         social platform marketing
# 22061       0.0           2            mobile application app
# 22075       0.0           0         social platform marketing
# 22076       0.0           4             customer product user
# 22078       0.0           4             customer product user
# 22079       0.0           2            mobile application app
# 22082       0.0           4             customer product user
# 22083       0.0           9                service cloud data
# 22085       0.0           3        software solution provides
# 22086       0.0           5                    real time data
# 22087       0.0           5                    real time data
# 22088       0.0           4             customer product user
# 22090       0.0           7       company technology research
# 22091       0.0           4             customer product user
# 22092       0.0           4             customer product user
# 22093       0.0           4             customer product user
# 22094       0.0           6         analytics data predictive
# 22095       0.0           4             customer product user
# 22096       0.0           4             customer product user
# 22097       0.0           4             customer product user
# 22098       0.0           5                    real time data
# 22099       0.0           4             customer product user
# 22101       0.0           4             customer product user
# 22102       0.0           4             customer product user
# 22103       0.0           2            mobile application app
# 22104       0.0           4             customer product user
# 22108       0.0           5                    real time data
# 22111       0.0           2            mobile application app
#
# [12658 rows x 6 columns]

# %%
df1 = merge_data_select.groupby('cluster_name')['acquired'].sum()
#df1['count'] = merge_data_select.groupby('cluster_name').count()

# %%
df1
# Out:
# cluster_name
# analytics data predictive            49.0
# business intelligence artificial     74.0
# company technology research          43.0
# customer product user               277.0
# data big platform                    57.0
# mobile application app              111.0
# real time data                       78.0
# service cloud data                   39.0
# social platform marketing           152.0
# software solution provides           75.0
# Name: acquired, dtype: float64

# %%
df2 = merge_data_select.groupby('cluster_name')['acquired'].count()

# %%
print df2
# Out:
# cluster_name
# analytics data predictive            572
# business intelligence artificial    1223
# company technology research          857
# customer product user               3148
# data big platform                    833
# mobile application app              1058
# real time data                       901
# service cloud data                   614
# social platform marketing           2176
# software solution provides          1276
# Name: acquired, dtype: int64

# %%
acq_ration = (df1/df2)*100

# %%
print acq_ration
# Out:
# cluster_name
# analytics data predictive            8.566434
# business intelligence artificial     6.050695
# company technology research          5.017503
# customer product user                8.799238
# data big platform                    6.842737
# mobile application app              10.491493
# real time data                       8.657048
# service cloud data                   6.351792
# social platform marketing            6.985294
# software solution provides           5.877743
# Name: acquired, dtype: float64
