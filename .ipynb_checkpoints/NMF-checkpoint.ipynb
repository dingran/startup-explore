# %%
# %pylab inline
# %config InlineBackend.figure_format = 'png'
from __future__ import division
import seaborn as sns
import sklearn as sk
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from nltk.stem.snowball import SnowballStemmer
import pandas as pd
import sys
import graphlab
import unicodedata
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
sns.set_context({'figure.figsize': [12, 7]})
sns.set_context(rc={'lines.markeredgewidth': 0.1})
sns.set_style('white')
sns.set_color_codes()
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.preprocessing import normalize
from sklearn.manifold import TSNE
from sklearn.utils import resample
print 'startup script successful'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:80% !important; }</style>
# startup script successful

# %%
def print_top_words(model, feature_names, n_top_words=20):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

from nltk.stem import WordNetLemmatizer
import re
token_pattern = re.compile(r"(?u)\b\w\w+\b")


class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in token_pattern.findall(doc)]

# %%
crunch_data=pd.read_csv('overall_company_list.csv')
kickstart_data=pd.read_csv('proj_list_tech_top200pages_full.csv')
angellist_data=pd.read_csv('results_so_far_2016101710pm.csv')
# unify the column name
kickstart_data.rename(columns={'description':'Description'},inplace=True)
angellist_data.rename(columns={'product_desc':'Description'},inplace=True)
#merge data
merge_data=crunch_data.append([kickstart_data,angellist_data])
# remove \n from descriptions
merge_data['Description']=merge_data['Description'].str.replace('\n',' ')
# merge_data['Description']=merge_data['Description'].str.replace('\\',' ')

merge_data=merge_data.dropna(subset=['Description'])
# turn into graphlab
# startup_data=graphlab.SFrame(merge_data['Description'])
# startup_data.rename({'X1':'Description'})

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=3000,
                                   tokenizer=LemmaTokenizer(),
                                   stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(merge_data['Description'])

# %%
nmf = NMF(n_components=10, random_state=1, 
          alpha=.1, l1_ratio=.5, max_iter=500).fit(tfidf)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, 10)
# Out:
# Topic #0:
# help people world customer product make online user new way
# Topic #1:
# data big science driven visualization analysis machine platform cloud enterprise
# Topic #2:
# analytics predictive provides retail advanced tool healthcare financial business provider
# Topic #3:
# intelligence business artificial enterprise competitive small research human machine market
# Topic #4:
# mobile application app web user apps device development developer game
# Topic #5:
# based location cloud user offer service saas game sharing networking
# Topic #6:
# social medium network content brand engagement networking discovery management optimization
# Topic #7:
# platform marketing digital brand advertising online agency customer content engagement
# Topic #8:
# company service technology software solution provides research development management market
# Topic #9:
# real time estate insight delivers analysis information place feedback news
# ()

# %%
def plot_top_words(model, feature_names, topic_idx, n_top_words=10):
#     for topic_idx, topic in enumerate(model.components_):
    topic=normalize(model.components_[topic_idx].reshape(1,-1))[0]
    sorted_idx=topic.argsort()[:-n_top_words - 1:-1]
    print("Topic #%d:" % topic_idx)
    features=[feature_names[i] for i in sorted_idx]
    print(" ".join(features))
    ax = sns.barplot(x=range(10),y=topic[sorted_idx])
    feature_id=0
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+0.15, height-0.1, '{}'.format(features[feature_id]))
        feature_id+=1

# %%
fig=figure(figsize=(15,20))
for i in range(10):
    subplot(10,1,i+1)
    plot_top_words(nmf,tfidf_feature_names,i)
# Out:
# Topic #0:
# help people world customer product make online user new way
# Topic #1:
# data big science driven visualization analysis machine platform cloud enterprise
# Topic #2:
# analytics predictive provides retail advanced tool healthcare financial business provider
# Topic #3:
# intelligence business artificial enterprise competitive small research human machine market
# Topic #4:
# mobile application app web user apps device development developer game
# Topic #5:
# based location cloud user offer service saas game sharing networking
# Topic #6:
# social medium network content brand engagement networking discovery management optimization
# Topic #7:
# platform marketing digital brand advertising online agency customer content engagement
# Topic #8:
# company service technology software solution provides research development management market
# Topic #9:
# real time estate insight delivers analysis information place feedback news

# %%
mapping = TSNE(n_components=2,init='pca', random_state=0)

# %%
X=nmf.transform(tfidf)

# %%
embed=mapping.fit_transform(resample(X,n_samples=1000,random_state=0))

# %%
scatter(embed[:,0],embed[:,1],s=5,alpha=0.5,color='k')
